# %%
# !pip install bertopic
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.4/143.4 kB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 55.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.8/90.8 kB 10.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 9.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached Cython-0.29.36-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 97.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 70.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 33.3 MB/s eta 0:00:00
# ...

# %%
# !pip install bertopic[visualization]
# Out:
# ...
# WARNING: bertopic 0.15.0 does not provide the extra 'visualization'
# ...

# %%
#import packages

import pandas as pd
import numpy as np
from bertopic import BERTopic
import string

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('./drive/MyDrive/NLP/Reviews_Filter.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.head(10)
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# 5   6  B006K2ZZ7K   ADT0SRK1MGOEU                   Twoapennything
# 6   7  B006K2ZZ7K  A1SP2KVKFXXRU1                David C. Sullivan
# 7   8  B006K2ZZ7K  A3JRGQVEQN31IQ               Pamela G. Williams
# 8   9  B000E7L2R4  A1MZYO9TZK0BBI                         R. James
# 9  10  B00171APVA  A21BT40VZCCYT4                    Carol A. Reed
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# ...

# %%
def clean_text(text):
  delete_dict ={sp_character: '' for sp_character in string.punctuation}
  delete_dict[' '] = ' '
  table = str.maketrans(delete_dict)
  text1 = text.translate(table)
  textArr = text1.split()
  text2 = ' '.join([w for w in textArr if (not w.isdigit() and (not w.isdigit() and len(w)>3))])

  return text2.lower()

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
df.dropna(axis = 0, how = 'any', inplace=True)

# %%
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
df['Text'] = df['Text'].apply(clean_text)

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

# %%
def remove_stopwords(text):
  textArr = text.split(' ')
  rem_text = " ".join([i for i in textArr if i not in stop_words])
  return rem_text

df['Text'] = df['Text'].apply(remove_stopwords)

# %%
df['Text'].head()
# Out:
# 0    bought several vitality canned food products f...
# 1    product arrived labeled jumbo salted peanutsth...
# 2    confection around centuries light pillowy citr...
# 3    looking secret ingredient robitussin believe f...
# 4    great taffy great price wide assortment yummy ...
# Name: Text, dtype: object

# %%
model = BERTopic(verbose=True)

docs = df.Text.to_list()
topics, probabilities = model.fit_transform(docs)
# Out:
# ...
# Batches:   0%|          | 0/469 [00:00<?, ?it/s]
# 2023-10-20 07:46:54,116 - BERTopic - Transformed documents to Embeddings
# 2023-10-20 07:47:41,359 - BERTopic - Reduced dimensionality
# 2023-10-20 07:47:42,669 - BERTopic - Clustered reduced embeddings

# %%
model.get_topic_freq().head(11)
# Out:
#      Topic  Count
# 0       -1   5071
# 7        0    527
# 51       1    491
# 50       2    419
# 33       3    395
# 12       4    300
# 52       5    248
# 142      6    210
# 4        7    204
# 107      8    198
# 5        9    154

# %%
model.get_topic(0)
# Out:
# [('shipping', 0.019486005023689117),
#  ('item', 0.018164965134723397),
#  ('product', 0.015600214113085958),
#  ('arrived', 0.015553622491781572),
#  ('price', 0.015287665015157591),
#  ('order', 0.01341514358571133),
#  ('amazon', 0.013063837707511891),
#  ('service', 0.011569819023149465),
#  ('creamers', 0.010793644355720739),
#  ('shipped', 0.010510116987492176)]

# %%
model.get_topic(1)
# Out:
# [('chips', 0.06918613904084786),
#  ('kettle', 0.02869951339800251),
#  ('potato', 0.025172673577138475),
#  ('chip', 0.021121639174713075),
#  ('vinegar', 0.019859222222130456),
#  ('salt', 0.01548298962396225),
#  ('bags', 0.012948804484501607),
#  ('spicy', 0.009411659355910224),
#  ('lays', 0.009378286243218771),
#  ('jalapeno', 0.009121200721339616)]

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model = BERTopic(nr_topics=20)

# %%
topics, probabilities = model.fit_transform(docs)
# Out:
# 2023-10-20 07:57:29,577 - BERTopic - Transformed documents to Embeddings
# 2023-10-20 07:57:47,226 - BERTopic - Reduced dimensionality
# 2023-10-20 07:57:47,868 - BERTopic - Clustered reduced embeddings
# 2023-10-20 07:57:51,155 - BERTopic - Reduced number of topics from 173 to 20

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Topik 0: opik ini mungkin berfokus pada makanan ringan seperti biskuit, kue, popcorn, dan bagaimana orang menyukai atau menganggapnya enak.
#
# Topik 1: Topik ini berkaitan dengan kopi dan segala sesuatu yang terkait dengannya, termasuk K-Cups, jenis biji kopi (beans), kopi tanpa kafein (decaf), dan berbagai citarasa kopi. Pembicaraan dalam topik ini mungkin mencakup diskusi tentang pilihan kopi dan preferensi rasa.
#
# Topik 2: Topik ini tampaknya berkaitan dengan makanan gurih, seperti keripik, garam, daging babi, saus, dan kulit babi (rinds). Orang-orang mungkin membahas berbagai jenis makanan gurih dan cara memasaknya.
#
# Topik 3: Topik ini berkaitan dengan minuman, khususnya jus jeruk, gula, minuman, dan soda. Pembicaraan dalam topik ini mungkin mencakup ulasan tentang minuman, termasuk apakah mereka mengandung gula atau berhubungan dengan minuman soda.
#
# Topik 4: Topik ini berkaitan dengan makanan dan camilan untuk hewan peliharaan, khususnya anjing. Orang-orang mungkin berbicara tentang camilan dan makanan untuk anjing, serta merek seperti "Newman's Own" yang terkait dengan produk ini.
#
# Topik 5: Topik ini berkaitan dengan produk cokelat, seperti cokelat, kakao, kue cokelat, cokelat gelap, dan berbagai jenis cokelat. Orang-orang mungkin berbicara tentang preferensi terkait dengan produk cokelat.
#
# Topik 6: Topik ini berkaitan dengan pembelian produk secara online, khususnya melalui Amazon. Orang-orang mungkin berbicara tentang pengiriman, pesanan, dan produk yang mereka beli, serta pengalaman berbelanja secara online.
#
# Topik 7: Topik ini tampaknya berkaitan dengan produk makanan yang berhubungan dengan susu, seperti susu, biji chia, produk berprotein tinggi, dan formula susu. Orang mungkin berbicara tentang nutrisi dan produk-produk ini.

# %%
model = BERTopic(nr_topics=10)

# %%
topics, probabilities = model.fit_transform(docs)
# Out:
# 2023-10-20 08:11:11,711 - BERTopic - Transformed documents to Embeddings
# 2023-10-20 08:11:30,144 - BERTopic - Reduced dimensionality
# 2023-10-20 08:11:30,809 - BERTopic - Clustered reduced embeddings
# 2023-10-20 08:11:33,047 - BERTopic - Reduced number of topics from 175 to 10

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Topik 0: Topik ini berkaitan dengan pendapat dan ulasan tentang rasa dan citarasa. Orang-orang mungkin berbicara tentang pengalaman mereka dengan makanan atau minuman dan menyatakan apakah mereka suka atau tidak suka, serta sejauh mana rasa atau citarasa itu dianggap baik atau hebat.
#
# Topik 1: Topik ini tampaknya berfokus pada kopi dan produk terkait seperti K-Cups dan mesin Keurig. Diskusi dalam topik ini mungkin mencakup topik seputar kopi, seperti berbagai citarasa kopi, preferensi terhadap kopi tertentu, dan pengalaman penggunaan mesin Keurig untuk menyeduh kopi.
#
# Topik 2: Topik ini tampaknya berkaitan dengan hewan peliharaan, seperti anjing dan kucing, serta makanan dan camilan yang digunakan untuk mereka. Mungkin topik ini mencakup pembahasan tentang jenis makanan dan camilan yang cocok untuk hewan peliharaan.
#
# Topik 3: Topik ini mungkin terkait dengan ulasan produk yang dibeli melalui Amazon, terutama dalam kategori makanan. Kemungkinan besar, orang membahas pengalaman mereka dalam memesan produk, termasuk harga dan kualitasnya.
#
# Topik 4: Topik ini mungkin berkaitan dengan kesehatan dan minuman. Kata kunci ini menunjukkan bahwa pembicaraan bisa mencakup topik seperti minuman yang berhubungan dengan energi, gangguan perut, dan masalah sinus, serta apakah minuman ini efektif.
#
# Topik 5: Topik ini berkaitan dengan tanaman, khususnya tanaman hias seperti bonsai dan pohon. Orang mungkin berbicara tentang pengiriman tanaman atau cara merawat tanaman ini.
#
# Topik 6: Topik ini tampaknya berkaitan dengan peralatan elektronik dan suara. Kata kunci ini mengindikasikan bahwa pembahasan mungkin berkisar pada hal-hal seperti perangkat audio, penutup jendela, dan koneksi listrik.
#
# Topik 7: Topik ini berkaitan dengan kegiatan memasak, terutama yang melibatkan bahan seperti aluminium foil, baking soda, dan pabrik penggilingan yang mungkin memproduksi bahan-bahan untuk memanggang.

# %%
model = BERTopic(nr_topics=40)

# %%
topics, probabilities = model.fit_transform(docs)
# Out:
# 2023-10-20 08:43:55,416 - BERTopic - Transformed documents to Embeddings
# 2023-10-20 08:44:12,964 - BERTopic - Reduced dimensionality
# 2023-10-20 08:44:13,624 - BERTopic - Clustered reduced embeddings
# 2023-10-20 08:44:15,816 - BERTopic - Reduced number of topics from 180 to 40

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Topik 0: Topik ini mungkin berkaitan dengan makanan ringan, daging babi, kulit babi panggang, penggunaan microwave, dan produk yang cocok untuk bayi. Pembicaraan dalam topik ini mungkin mencakup berbagai aspek terkait dengan makanan dan peralatan masak.
#
# Topik 1: Topik ini berfokus pada kopi dan segala sesuatu yang terkait dengannya, termasuk jenis pemanggangan kopi (roast), kopi tanpa kafein (decaf), K-Cups, dan citarasa kopi. Orang-orang mungkin berbicara tentang preferensi terkait dengan kopi dan cara menyeduhnya.
#
# Topik 2:  Topik ini berkaitan dengan minuman, khususnya jus jeruk, minuman soda, dan keputusan untuk beralih dari satu jenis minuman ke yang lain. Orang-orang mungkin berbicara tentang perubahan dalam pola minum mereka.
#
# Topik 3: Topik ini berkaitan dengan makanan dan camilan untuk hewan peliharaan, termasuk anjing dan kucing. Orang-orang mungkin berbicara tentang berbagai jenis makanan dan camilan yang diberikan kepada hewan peliharaan mereka.
#
# Topik 4: Topik ini berkaitan dengan pembelian produk secara online, terutama melalui Amazon. Orang-orang mungkin berbicara tentang produk yang mereka pesan, pengiriman, harga, dan pengalaman berbelanja online.
#
# Topik 5: Topik ini tampaknya berkaitan dengan makanan seperti saus, mie, sup, pasta, dan hidangan ayam. Orang-orang mungkin berbicara tentang resep, cara memasak, dan pengalaman kuliner yang melibatkan bahan-bahan ini.
#
# Topik 6: Topik ini berkaitan dengan produk cokelat, termasuk cokelat, kakao, permen licorice, cokelat gelap, dan berbagai jenis cokelat. Orang-orang mungkin berbicara tentang preferensi terkait dengan produk cokelat.
#
# Topik 7: Topik ini tampaknya berkaitan dengan makanan ringan seperti keripik kentang, kentang panggang, cuka, dan merek seperti Popchips. Orang-orang mungkin berbicara tentang berbagai jenis keripik dan preferensi terkait.
